# %%
import pandas as pd

# %%
df = pd.read_csv("heart.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
# checks no. of nulls
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# checks no. of duplicates
df.duplicated().sum()
# Out:
# 1

# %%
# keep=False allows me to see both duplicate rows

duplicate_rows = df[df.duplicated(keep=False)]
print(duplicate_rows)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 163   38    1   2       138   175    0        1      173      0      0.0
# 164   38    1   2       138   175    0        1      173      0      0.0
#
#      slope  ca  thal  target
# 163      2   4     2       1
# 164      2   4     2       1

# %%
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# 0

# %%
# visualization libraries
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Count plot using Seaborn
plt.figure(figsize=(8, 6))
sns.countplot(x='target', data=df, order= df['target'].value_counts().index)
plt.xlabel('target')
plt.ylabel('Count')
plt.title('Count Plot using Seaborn')
plt.show()
print("percentage of people who suffer from heart desease and that who don't in this dataset")
# Out:
# percentage of people who suffer from heart desease and that who don't in this dataset

# %%
# correlation between data and the target
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('feature importance using heat map')
plt.show()

# %% [markdown]
# observation : chest pain type ,the max heart rate achieved and the slope of the peak exercise ST segment are the most effective features on the target.

# %% [markdown]
# in case of the negative effectiveness: thalesmia , number of major vessels that are affected, ST depression induced by exercise relative to rest and the exercised induced angina affect the target negatively

# %%
# Plotting the relation between 'ca' and 'target'
plt.figure(figsize=(8, 6))
sns.countplot(x='ca', hue='target', data=df, palette='viridis')
plt.title('Relation between Number of Major Vessels (ca) and Heart Disease (target)')
plt.xlabel('Number of Major Vessels (ca)')
plt.ylabel('Count')
plt.legend(title='Heart Disease (target)', loc='upper right')
plt.show()

# %%
# plt.figure(figsize=(10, 6))
# sns.histplot(filtered_data['thalach'], bins=25, kde=True, color='red')
# plt.title('frequency of maximum heart rate achieved')
# plt.xlabel('max heart rate')
# plt.ylabel('Frequency')
# plt.show()
# print("observation: when maximum heart rate achieved increases the precentage of heart desease increases [150-180]")

# %%
df = pd.DataFrame(df)

# Plotting the relation between 'oldpeak' and 'target'
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='oldpeak', hue='target', multiple='stack', palette='viridis', bins=10)
plt.title('Relation between Oldpeak and Heart Disease (target)')
plt.xlabel('Oldpeak')
plt.ylabel('Count')
plt.legend(title='Heart Disease (target)', loc='upper right')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#df = pd.DataFrame(d)

# Plotting the relationship between 'cp' and 'target'
plt.figure(figsize=(8, 6))
sns.countplot(x='cp', hue='target', data=df, palette='viridis')
plt.title('Relation Between Chest Pain Type (cp) and Heart Disease (target)')
plt.xlabel('Chest Pain Type (cp)')
plt.ylabel('Count')
plt.legend(title='Heart Disease', loc='upper right', labels=['No (0)', 'Yes (1)'])
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='slope', hue='target', data=df, palette='coolwarm')
plt.title('Relation Between Slope and Heart Disease (target)')
plt.xlabel('Slope')
plt.ylabel('Count')
plt.legend(title='Heart Disease', loc='upper right', labels=['No (0)', 'Yes (1)'])
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='exang', hue='target', data=df, palette='cool')
plt.title('Relation Between Exercise-Induced Angina (exang) and Heart Disease (target)')
plt.xlabel('Exercise-Induced Angina (exang)')
plt.ylabel('Count')
plt.legend(title='Heart Disease', loc='upper right', labels=['No (0)', 'Yes (1)'])
plt.show()
print("exang is the most effective feature on heart desease negatively")
# Out:
# exang is the most effective feature on heart desease negatively

# %%
# removing outliers, where it is unacceptable for data to be '0' 

zero_not_accepted = ['age', 'trestbps', 'chol',]

for column in zero_not_accepted:
    zero_count = (df[column] == 0).sum()
    print(f"Column '{column}' has {zero_count} zeros")
# Out:
# Column 'age' has 0 zeros
# Column 'trestbps' has 0 zeros
# Column 'chol' has 0 zeros

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plotting box plots for key columns
columns_to_check = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']
for column in columns_to_check:
    plt.figure(figsize=(8,4))
    sns.boxplot(x=df[column])
    plt.title(f'Box Plot of {column}')
    plt.show()

# %%
#pie chart of the percentage of the gender with heart desease
# Filter the data where 'target' is equal to 1
filtered_data = df[df['target'] == 1]
# Get the value counts of the 'Gender' column for the filtered data
gender_counts = filtered_data['sex'].value_counts()

# Pie chart using Matplotlib
plt.figure(figsize=(8, 8))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%.1f%%', colors=plt.cm.Paired(range(len(gender_counts))))
plt.title('Percentage of Male and Female that has heart desease M=1 F=0')
plt.show()
print("observation: males are more likely to suffer from heart desease")
# Out:
# observation: males are more likely to suffer from heart desease

# %%
# Histogram of the frequency of ages who suffer from heart desease
plt.figure(figsize=(10, 6))
sns.histplot(filtered_data['age'], bins=25, kde=True, color='red')
plt.title('frequency of ages who suffer from heart desease')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
print("age that are more likely to suffer from heart desease (40-60)")


normal_data = df[df['target'] == 0]
plt.figure(figsize=(10, 6))
sns.histplot(normal_data['age'], bins=25, kde=True, color='blue')
plt.title('frequency of ages who dont suffer from heart desease')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
# Out:
# age that are more likely to suffer from heart desease (40-60)

# %%
filtered_data = df[df['target'] == 1]
sns.histplot(filtered_data['chol'], kde=True)
plt.title('Cholesterol Distribution')
plt.show()

# %% [markdown]
# # the average rate of cholesterol readings of people who suffer from heart desease [180-350]

# %% [markdown]
# # Setting limits to the data

# %%
# capping data, i.e reducing data to the 1st and 99th percentile in order to avoid extreme values. 
# (fixing extreme values to make sure they aren’t too different from the rest)

def cap_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df[column] = df[column].clip(lower_bound, upper_bound)

columns_to_cap = ['trestbps', 'chol', 'oldpeak', 'thalach']
for col in columns_to_cap:
    cap_outliers(df, col)

# %% [markdown]
# # Rescaling The Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
from sklearn.preprocessing import MinMaxScaler
from imblearn.over_sampling import SMOTE  # to use SMOTE 
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# getting the numerical columns
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Fit and transform the numerical columns
df_scaled = df.copy()
df_scaled[numerical_cols] = scaler.fit_transform(df[numerical_cols])  
# rescaling the data, to change the range of extreme values to fit within a certain range 
# this ensures that all the data in the data frame contributes to the machine learning process

print("\nScaled Data:")
print(df_scaled)
# Out:
# Scaled Data:
#           age  sex        cp  trestbps      chol  fbs  restecg   thalach  \
# 0    0.708333  1.0  1.000000  0.671053  0.437852  1.0      0.0  0.558855
# 1    0.166667  1.0  0.666667  0.473684  0.507417  0.0      0.5  0.872747
# 2    0.250000  0.0  0.333333  0.473684  0.319182  0.0      0.0  0.745493
# 3    0.562500  1.0  0.333333  0.342105  0.450128  0.0      0.5  0.796394
# 4    0.583333  0.0  0.000000  0.342105  0.932992  0.0      0.5  0.669141
# ..        ...  ...       ...       ...       ...  ...      ...       ...
# 298  0.583333  0.0  0.000000  0.605263  0.470588  0.0      0.5  0.329799
# 299  0.333333  1.0  1.000000  0.210526  0.564706  0.0      0.5  0.406151
# 300  0.812500  1.0  0.000000  0.657895  0.274169  1.0      0.5  0.482503
# 301  0.583333  1.0  0.000000  0.473684  0.020460  0.0      0.5  0.261930
# 302  0.583333  0.0  0.333333  0.473684  0.450128  0.0      0.0  0.762460
#
#      exang  oldpeak  slope    ca      thal  target
# ...

# %% [markdown]
# # Upscaling The Data

# %%
selected_features = ['oldpeak', 'thalach','thal', 'ca', 'cp', 'age', 'chol','target']  # list based on feature importance analysis
df_selected = df_scaled[selected_features]

# %%
df_selected
# Out:
#      oldpeak   thalach      thal    ca        cp       age      chol  target
# 0      0.575  0.558855  0.333333  0.00  1.000000  0.708333  0.437852     1.0
# 1      0.875  0.872747  0.666667  0.00  0.666667  0.166667  0.507417     1.0
# 2      0.350  0.745493  0.666667  0.00  0.333333  0.250000  0.319182     1.0
# 3      0.200  0.796394  0.666667  0.00  0.333333  0.562500  0.450128     1.0
# 4      0.150  0.669141  0.666667  0.00  0.000000  0.583333  0.932992     1.0
# ..       ...       ...       ...   ...       ...       ...       ...     ...
# 298    0.050  0.329799  1.000000  0.00  0.000000  0.583333  0.470588     0.0
# 299    0.300  0.406151  1.000000  0.00  1.000000  0.333333  0.564706     0.0
# 300    0.850  0.482503  1.000000  0.50  0.000000  0.812500  0.274169     0.0
# 301    0.300  0.261930  1.000000  0.25  0.000000  0.583333  0.020460     0.0
# 302    0.000  0.762460  0.666667  0.25  0.333333  0.583333  0.450128     0.0
#
# [302 rows x 8 columns]

# %%
# splitting the data 
x = df_selected.drop(columns=['target'])  
y = df_selected['target']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=40)

# %%
smote = SMOTE(random_state=42)
x_train_smote, y_train_smote = smote.fit_resample(x_train, y_train)

# %%
# rechecking the distribution of the target column
print("Original target distribution:", y_train.value_counts())
print("Resampled target distribution:", y_train_smote.value_counts())
# Out:
# Original target distribution: target
# 1.0    129
# 0.0    112
# Name: count, dtype: int64
# Resampled target distribution: target
# 1.0    129
# 0.0    129
# Name: count, dtype: int64

# %%
# Train a Decision Tree Classifier
decision_tree = DecisionTreeClassifier(random_state=42)   # initializing the decision tree model
decision_tree.fit(x_train_smote, y_train_smote)           # training the decision model on the training data
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# Train a Random Forest Classifier
random_forest = RandomForestClassifier(random_state=42)
random_forest.fit(x_train_smote, y_train_smote)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Get feature importances
dt_feature_importances = decision_tree.feature_importances_
rf_feature_importances = random_forest.feature_importances_

# %%
# Create a DataFrame to display feature importances
features = x.columns
importance_df = pd.DataFrame({
    'Feature': features,
    'Decision_Tree_Importance': dt_feature_importances,
    'Random_Forest_Importance': rf_feature_importances
}).sort_values(by='Random_Forest_Importance', ascending=False)

importance_df
# Out:
#    Feature  Decision_Tree_Importance  Random_Forest_Importance
# 1  thalach                  0.130800                  0.196265
# 2     thal                  0.148099                  0.155734
# 4       cp                  0.276251                  0.147270
# 0  oldpeak                  0.052517                  0.144120
# 5      age                  0.175225                  0.128710
# 6     chol                  0.095126                  0.114241
# 3       ca                  0.121982                  0.113661

# %%
# importance threshold between ~ features > 0.05

# %% [markdown]
# # KNN Model with 7 neighbors
# knn_model = KNeighborsClassifier(n_neighbors=7)
# knn_model.fit(x_train, y_train)
#
# # Predictions for both training and test sets
# knn_predictions_train = knn_model.predict(x_train)
# knn_predictions_test = knn_model.predict(x_test)
#
# # Calculate accuracy for both sets
# train_accuracy = accuracy_score(y_train, knn_predictions_train)
# test_accuracy = accuracy_score(y_test, knn_predictions_test)
#
# print(f"KNN (7 neighbors) - Training Accuracy: {train_accuracy:.2f}")
# print(f"KNN (7 neighbors) - Test Accuracy: {test_accuracy:.2f}")

# %%
# choosing the K, using 'n' the number of data points
import math
math.sqrt(len(y_test))
# although k is a hyperparameter, we found that K=7 was the best no. of neighbors
# Out:
# 7.810249675906654

# %%
# KNN Model with 7 neighbors
knn_model = KNeighborsClassifier(n_neighbors=7)
knn_model.fit(x_train, y_train)

# Predictions for both training and test sets
knn_predictions_train = knn_model.predict(x_train)
knn_predictions_test = knn_model.predict(x_test)

# Calculate accuracy for both sets
train_accuracy = accuracy_score(y_train, knn_predictions_train)
test_accuracy = accuracy_score(y_test, knn_predictions_test)

print(f"KNN (7 neighbors) - Training Accuracy: {train_accuracy:.2f}")
print(f"KNN (7 neighbors) - Test Accuracy: {test_accuracy:.2f}")
# Out:
# KNN (7 neighbors) - Training Accuracy: 0.83
# KNN (7 neighbors) - Test Accuracy: 0.87

# %%
# KNN Model with 7 neighbors
knn_model = KNeighborsClassifier(n_neighbors=7)
knn_model.fit(x_train, y_train)

# Predictions for both training and test sets
knn_predictions_train = knn_model.predict(x_train)
knn_predictions_test = knn_model.predict(x_test)

# Calculate accuracy for both sets
train_accuracy = accuracy_score(y_train, knn_predictions_train)
test_accuracy = accuracy_score(y_test, knn_predictions_test)

print(f"KNN (7 neighbors) - Training Accuracy: {train_accuracy:.2f}")
print(f"KNN (7 neighbors) - Test Accuracy: {test_accuracy:.2f}")
# Out:
# KNN (7 neighbors) - Training Accuracy: 0.83
# KNN (7 neighbors) - Test Accuracy: 0.87

# %%
# KNN Model with 7 neighbors
knn_model = KNeighborsClassifier(n_neighbors=7)
knn_model.fit(x_train, y_train)

# Predictions for both training and test sets
knn_predictions_train = knn_model.predict(x_train)
knn_predictions_test = knn_model.predict(x_test)

# Calculate accuracy for both sets
train_accuracy = accuracy_score(y_train, knn_predictions_train)
test_accuracy = accuracy_score(y_test, knn_predictions_test)

print(f"KNN (7 neighbors) - Training Accuracy: {train_accuracy:.2f}")
print(f"KNN (7 neighbors) - Test Accuracy: {test_accuracy:.2f}")
# Out:
# KNN (7 neighbors) - Training Accuracy: 0.83
# KNN (7 neighbors) - Test Accuracy: 0.87

# %%
# KNN Model with 7 neighbors
knn_model = KNeighborsClassifier(n_neighbors=7)
knn_model.fit(x_train, y_train)

# Predictions for both training and test sets
knn_predictions_train = knn_model.predict(x_train)
knn_predictions_test = knn_model.predict(x_test)

# Calculate accuracy for both sets
train_accuracy = accuracy_score(y_train, knn_predictions_train)
test_accuracy = accuracy_score(y_test, knn_predictions_test)

print(f"KNN (7 neighbors) - Training Accuracy: {train_accuracy:.2f}")
print(f"KNN (7 neighbors) - Test Accuracy: {test_accuracy:.2f}")
# Out:
# KNN (7 neighbors) - Training Accuracy: 0.83
# KNN (7 neighbors) - Test Accuracy: 0.87

# %% [markdown]
# # Decision Trees

# %%
# splitting the data 
x = df_scaled.drop(columns=['target'])  
y = df_scaled['target']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=40)

# %%
smote = SMOTE(random_state=42)
x_train_smote, y_train_smote = smote.fit_resample(x_train, y_train)

# %%
# Decision Tree
decision_tree = DecisionTreeClassifier(random_state=42)
decision_tree.fit(x_train_smote, y_train_smote)
dt_pred = decision_tree.predict(x_test)

# %%
# Decision Tree Evaluation
print("\nDecision Tree:")
print(f"Accuracy: {accuracy_score(y_test, dt_pred)}")
print(f"Classification Report:\n{classification_report(y_test, dt_pred)}")
# Out:
# Decision Tree:
# Accuracy: 0.7704918032786885
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.77      0.74        26
#          1.0       0.82      0.77      0.79        35
#
#     accuracy                           0.77        61
#    macro avg       0.77      0.77      0.77        61
# weighted avg       0.77      0.77      0.77        61

# %% [markdown]
# # Random Forest

# %%
# Random Forest
random_forest = RandomForestClassifier(random_state=42)
random_forest.fit(x_train_smote, y_train_smote)
rf_pred = random_forest.predict(x_test)

# %%
# Random Forest Evaluation
print("\nRandom Forest:")
print(f"Accuracy: {accuracy_score(y_test, rf_pred)}")
print(f"Classification Report:\n{classification_report(y_test, rf_pred)}")
# Out:
# Random Forest:
# Accuracy: 0.9016393442622951
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.92      0.89        26
#          1.0       0.94      0.89      0.91        35
#
#     accuracy                           0.90        61
#    macro avg       0.90      0.90      0.90        61
# weighted avg       0.90      0.90      0.90        61

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# Initialize the Decision Tree classifier
dtree = DecisionTreeClassifier(criterion='gini', max_depth=5, random_state=42)

# Fit the model to the training data
dtree.fit(x_train_smote, y_train_smote)

# Predict on the test set
y_test_pred = dtree.predict(x_test)

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_test_pred)

# Print the confusion matrix
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[20  6]
#  [ 4 31]]

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train_smote, y_train_smote)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
# Logistic Regression Evaluation
print("Logistic Regression:")
print(f"Accuracy: {accuracy_score(y_test,y_pred)}")
class_report = classification_report(y_test, y_pred)
print("Classification Report:\n", class_report)
# Out:
# Logistic Regression:
# Accuracy: 0.9180327868852459
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.89      0.92      0.91        26
#          1.0       0.94      0.91      0.93        35
#
#     accuracy                           0.92        61
#    macro avg       0.92      0.92      0.92        61
# weighted avg       0.92      0.92      0.92        61

# %% [markdown]
# # Tree Classifier - Gini Index

# %%
# Initialize the Decision Tree classifier with Gini impurity criterion
dtree = DecisionTreeClassifier(criterion='gini', max_depth=5, random_state=42)

# %%
# Fit the model to the training data
dtree.fit(x_train_smote, y_train_smote)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=42)

# %%
# Predict on the training set
y_train_pred = dtree.predict(x_train_smote)

# %%
# Predict on the test set
y_test_pred = dtree.predict(x_test)

# %%
# Calculate accuracy for both sets
train_accuracy = accuracy_score(y_train_smote, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print(f"Training Accuracy: {train_accuracy:.2f}")
print(f"Test Accuracy: {test_accuracy:.2f}")
# Out:
# Training Accuracy: 0.93
# Test Accuracy: 0.84

# %% [markdown]
# # Decision Tree Classifier with criterion entropy

# %%
from sklearn.metrics import accuracy_score

# %%
# Initialize the Decision Tree classifier with entropy criterion
dtree = DecisionTreeClassifier(criterion='entropy', max_depth=5, random_state=42)

# Fit the model to the training data
dtree.fit(x_train_smote, y_train_smote)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, random_state=42)

# %%
# Predict on the training set
y_train_pred = dtree.predict(x_train_smote)

# %%
# Predict on the test set
y_test_pred = dtree.predict(x_test)

# %%
# Calculate accuracy for both sets
train_accuracy = accuracy_score(y_train_smote, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

# %%
print(f"Training Accuracy: {train_accuracy:.2f}")
print(f"Test Accuracy: {test_accuracy:.2f}")
# Out:
# Training Accuracy: 0.92
# Test Accuracy: 0.82

# %% [markdown]
# # Bagging Ensemble

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

# Create a Bagging Classifier with Decision Trees as base estimators
bagging_model = BaggingClassifier(
    estimator=DecisionTreeClassifier(),  # Correct parameter name
    n_estimators=50,                     # Number of base models
    bootstrap=True,                      # Use bootstrap sampling
    n_jobs=-1,                           # Use all available cores
    random_state=42                      # For reproducibility
)

# Train the Bagging model
bagging_model.fit(x_train, y_train)

# Make predictions
y_pred = bagging_model.predict(x_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
# Calculate accuracy for both sets
train_accuracy = accuracy_score(y_train_smote, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print(f"Training Accuracy: {train_accuracy:.2f}")
print(f"Test Accuracy: {test_accuracy:.2f}")
print(f"Accuracy of Bagging Classifier: {accuracy:.2f}")
# Out:
# Training Accuracy: 0.92
# Test Accuracy: 0.82
# Accuracy of Bagging Classifier: 0.82

# %% [markdown]
# # Boosting Ensemble

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score

# AdaBoost model
ada_boost_model = AdaBoostClassifier(n_estimators=100, random_state=42)
ada_boost_model.fit(x_train, y_train)

# Predictions for both training and test sets
y_train_pred = ada_boost_model.predict(x_train)
y_test_pred = ada_boost_model.predict(x_test)

# Calculate accuracy for both sets
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print(f"AdaBoost - Training Accuracy: {train_accuracy:.2f}")
print(f"AdaBoost - Test Accuracy: {test_accuracy:.2f}")
# Out:
# AdaBoost - Training Accuracy: 0.95
# AdaBoost - Test Accuracy: 0.77
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(

# %% [markdown]
# # Stacking Ensemble

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

estimators = [
    ('knn', KNeighborsClassifier(n_neighbors=7)), 
    ('dt', DecisionTreeClassifier(random_state=42))
]

# Defining the Stacking Classifier
stacking_model = StackingClassifier (
    estimators = estimators,
    final_estimator=LogisticRegression()
)

# Fit the model
stacking_model.fit(x_train, y_train)

# Predictions for both training and test sets
y_train_pred = stacking_model.predict(x_train)
y_test_pred = stacking_model.predict(x_test)

# Calculate accuracy for both sets
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print(f"Stacking - Training Accuracy: {train_accuracy:.2f}")
print(f"Stacking - Test Accuracy: {test_accuracy:.2f}")
# Out:
# Stacking - Training Accuracy: 0.93
# Stacking - Test Accuracy: 0.89

# %% [markdown]
# # Feature Engineering

# %%
# Define the bins and labels
bins = [0, 40, 60, 100]  # Age ranges: 0-40, 40-60, 60-100
labels = ['young', 'middle-aged', 'senior']  # Labels for the bins

# Create a new column with age categories
df['age_group'] = pd.cut(df['age'], bins=bins, labels=labels, right=False)


age_target_counts = df.groupby(['age_group', 'target']).size().unstack().fillna(0)

# Plotting
age_target_counts.plot(kind='bar', stacked=True)
plt.title('Count of Target by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.legend(title='Target', loc='upper right')

# Show the plot
plt.show()
# Out:
# C:\Users\msi\AppData\Local\Temp\ipykernel_384488\1586016118.py:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_target_counts = df.groupby(['age_group', 'target']).size().unstack().fillna(0)

# %%
# Analyze the percentage of heart disease cases across different age groups.

# Define age groups (e.g., <40, 40-50, 50-60, 60+)
bins = [20, 40, 50, 60, 70, 80]
labels = ['<40', '40-50', '50-60', '60-70', '70+']
df['age_group'] = pd.cut(df['age'], bins=bins, labels=labels)

# Percentage of heart disease in each age group
age_heart_disease = df.groupby('age_group')['target'].mean() * 100
age_heart_disease.plot(kind='bar', color='lightgreen')
plt.title('Heart Disease by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Percentage with Heart Disease')
plt.show()
# Out:
# C:\Users\msi\AppData\Local\Temp\ipykernel_384488\4244475004.py:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_heart_disease = df.groupby('age_group')['target'].mean() * 100

# %%
# Analyze how gender and age group interact to affect heart disease risk.

# Pivot table to see the interaction
gender_age_heart_disease = df.pivot_table(values='target', index='age_group', columns='sex', aggfunc='mean') * 100
gender_age_heart_disease.plot(kind='bar', figsize=(10, 6), color=['pink', 'blue'])
plt.title('Heart Disease by Age Group and Gender')
plt.xlabel('Age Group')
plt.ylabel('Percentage with Heart Disease')
plt.show()
# Out:
# C:\Users\msi\AppData\Local\Temp\ipykernel_384488\2118383016.py:4: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   gender_age_heart_disease = df.pivot_table(values='target', index='age_group', columns='sex', aggfunc='mean') * 100
